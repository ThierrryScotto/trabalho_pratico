# %% [markdown]
# <a href="https://colab.research.google.com/github/ThierrryScotto/trabalho_pratico/blob/main/preprocessamento_heat_and_heart_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libs

# %%
# !pip install metpy --quiet

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from metpy.calc import heat_index
from metpy.units import units

# %% [markdown]
# # Helpers

# %% [markdown]
# ### Constantes

# %%
features_datasus = ["hospitalizations", "average_stay", "deaths", "mortality_rate"]

# %% [markdown]
# ### Funções

# %% [markdown]
# # Dataset

# %%
url = "https://raw.githubusercontent.com/ThierrryScotto/trabalho_pratico/refs/heads/main/datasets/INMET.csv"

# %%
dataset = pd.read_csv(url, sep=";")
dataset
# Out:
# <ipython-input-5-ad7fa1b16750>:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(url, sep=";")
#               DATA      HORA PRECIPITACAO_TOTAL_HORARIO_MM  \
# 0       2000-09-22     22:00                             0
# 1       2000-09-22     21:00                             0
# 2       2000-09-22     20:00                             0
# 3       2000-09-22     19:00                             0
# 4       2000-09-22     18:00                             0
# ...            ...       ...                           ...
# 211339  2024-10-31  0200 UTC                             0
# 211340  2024-10-31  0100 UTC                             0
# 211341  2024-10-31  2300 UTC                             0
# 211342  2024-10-31  1000 UTC                             0
# 211343  2024-10-31  2200 UTC                             0
#
#        PRESSAO_ATMOSFERICA_NIVEL_ESTACAO_HORARIA_MB  \
# 0                                            1014,1
# 1                                            1014,3
# 2                                              1014
# 3                                              1014
# 4                                            1014,1
# ...                                             ...
# 211339                                       1009,8
# 211340                                       1009,9
# 211341                                       1006,1
# 211342                                       1009,7
# 211343                                       1005,7
#
#        PRESSAO_ATMOSFERICA_MAX.NA_HORA_ANT_AUT_MB  \
# 0                                          1014,3
# 1                                          1014,3
# 2                                            1014
# 3                                          1014,2
# 4                                          1014,8
# ...                                           ...
# 211339                                       1010
# 211340                                       1010
# 211341                                     1006,2
# 211342                                     1009,7
# 211343                                     1005,7
#
#        PRESSAO_ATMOSFERICA_MIN_NA_HORA_ANT_AUT_MB RADIACAO_GLOBAL_KJ_m2  \
# 0                                            1014                    13
# 1                                            1014                   448
# 2                                          1013,9                  1252
# 3                                          1013,9                  1924
# 4                                          1014,1                  2791
# ...                                           ...                   ...
# 211339                                     1009,8                   NaN
# 211340                                     1009,8                   NaN
# 211341                                     1005,5                   NaN
# 211342                                     1009,1                 464,1
# 211343                                     1005,1                  66,9
#
#        TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C TEMPERATURA_PONTO_DE_ORVALHO_C  \
# 0                                        15,7                            9,8
# 1                                        17,8                           10,7
# 2                                        19,8                            9,8
# 3                                        20,9                            7,4
# 4                                        20,9                            6,9
# ...                                       ...                            ...
# 211339                                   20,8                           17,9
# 211340                                   21,1                           18,2
# 211341                                   22,6                           17,5
# 211342                                   21,8                           17,7
# 211343                                   23,4                           17,9
#
#        TEMPERATURA_MAXIMA_NA_HORA_ANT_AUT_C  \
# 0                                      17,7
# 1                                      19,8
# 2                                      21,2
# 3                                      21,2
# 4                                      21,3
# ...                                     ...
# 211339                                 21,2
# 211340                                 21,4
# 211341                                 23,4
# 211342                                 21,8
# 211343                                 25,1
#
#        TEMPERATURA_MINIMA_NA_HORA_ANT_AUT_C  \
# 0                                      15,6
# 1                                      17,8
# 2                                      19,7
# 3                                      20,3
# 4                                      20,2
# ...                                     ...
# 211339                                 20,8
# 211340                                 21,1
# 211341                                 22,6
# 211342                                 19,7
# 211343                                 23,4
#
#        TEMPERATURA_ORVALHO_MAX_NA_HORA_ANT_AUT_C  \
# 0                                           10,9
# 1                                           10,7
# 2                                           10,3
# 3                                            8,3
# 4                                            9,6
# ...                                          ...
# 211339                                      18,2
# 211340                                      18,4
# 211341                                      17,9
# 211342                                        18
# 211343                                      18,1
#
#        TEMPERATURA_ORVALHO_MIN_NA_HORA_ANT_AUT_C  \
# 0                                            9,8
# 1                                            9,4
# 2                                            6,5
# 3                                            6,4
# 4                                            6,2
# ...                                          ...
# 211339                                      17,9
# 211340                                      18,2
# 211341                                      17,5
# 211342                                      17,3
# 211343                                      17,9
#
#         UMIDADE_REL_MAX_NA_HORA_ANT_AUT_%  UMIDADE_REL_MIN_NA_HORA_ANT_AUT_%  \
# 0                                    70.0                               62.0
# 1                                    63.0                               51.0
# 2                                    54.0                               40.0
# 3                                    45.0                               39.0
# 4                                    48.0                               40.0
# ...                                   ...                                ...
# 211339                               84.0                               83.0
# 211340                               84.0                               83.0
# 211341                               74.0                               72.0
# 211342                               87.0                               78.0
# 211343                               72.0                               65.0
#
#         UMIDADE_RELATIVA_DO_AR_HORARIA_%  VENTO_DIRECAO_HORARIA_GR  \
# 0                                   68.0                     106.0
# 1                                   63.0                     112.0
# 2                                   52.0                     141.0
# 3                                   42.0                     295.0
# 4                                   40.0                     246.0
# ...                                  ...                       ...
# 211339                              84.0                     117.0
# 211340                              83.0                     114.0
# 211341                              73.0                     125.0
# 211342                              78.0                     130.0
# 211343                              72.0                     124.0
#
#        VENTO_RAJADA_MAXIMA_M/S VENTO_VELOCIDADE_HORARIA_M/S  Unnamed: 19
# 0                          6,3                          2,4          NaN
# 1                          4,7                          2,2          NaN
# 2                          4,3                          1,7          NaN
# 3                          3,9                          1,7          NaN
# 4                          5,2                          1,1          NaN
# ...                        ...                          ...          ...
# 211339                     7,7                            2          NaN
# 211340                    11,1                          2,4          NaN
# 211341                       6                            2          NaN
# 211342                     5,3                          1,3          NaN
# 211343                     8,4                          1,6          NaN
#
# [211344 rows x 20 columns]

# %% [markdown]
# # Pré-processamento INMET

# %%
features = ['DATA',
            'HORA',
            'TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C',
            'RADIACAO_GLOBAL_KJ_m2',
            'UMIDADE_RELATIVA_DO_AR_HORARIA_%',
            'VENTO_VELOCIDADE_HORARIA_M/S']

dataset = dataset[features]

# %%
dataset[features]
# Out:
#               DATA      HORA TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C  \
# 0       2000-09-22     22:00                                   15,7
# 1       2000-09-22     21:00                                   17,8
# 2       2000-09-22     20:00                                   19,8
# 3       2000-09-22     19:00                                   20,9
# 4       2000-09-22     18:00                                   20,9
# ...            ...       ...                                    ...
# 211339  2024-10-31  0200 UTC                                   20,8
# 211340  2024-10-31  0100 UTC                                   21,1
# 211341  2024-10-31  2300 UTC                                   22,6
# 211342  2024-10-31  1000 UTC                                   21,8
# 211343  2024-10-31  2200 UTC                                   23,4
#
#        RADIACAO_GLOBAL_KJ_m2  UMIDADE_RELATIVA_DO_AR_HORARIA_%  \
# 0                         13                              68.0
# 1                        448                              63.0
# 2                       1252                              52.0
# 3                       1924                              42.0
# 4                       2791                              40.0
# ...                      ...                               ...
# 211339                   NaN                              84.0
# 211340                   NaN                              83.0
# 211341                   NaN                              73.0
# 211342                 464,1                              78.0
# 211343                  66,9                              72.0
#
#        VENTO_VELOCIDADE_HORARIA_M/S
# 0                               2,4
# 1                               2,2
# 2                               1,7
# 3                               1,7
# 4                               1,1
# ...                             ...
# 211339                            2
# 211340                          2,4
# 211341                            2
# 211342                          1,3
# 211343                          1,6
#
# [211344 rows x 6 columns]

# %%
dataset.describe()
# Out:
#        UMIDADE_RELATIVA_DO_AR_HORARIA_%
# count                     211096.000000
# mean                        -232.412471
# std                         1735.624458
# min                        -9999.000000
# 25%                           63.000000
# 50%                           79.000000
# 75%                           89.000000
# max                          100.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211344 entries, 0 to 211343
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   DATA                                    211344 non-null  object
#  1   HORA                                    211344 non-null  object
#  2   TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C  211101 non-null  object
#  3   RADIACAO_GLOBAL_KJ_m2                   187430 non-null  object
#  4   UMIDADE_RELATIVA_DO_AR_HORARIA_%        211096 non-null  float64
#  5   VENTO_VELOCIDADE_HORARIA_M/S            211050 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 9.7+ MB

# %%
dataset.isna().sum()
# Out:
# DATA                                          0
# HORA                                          0
# TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C      243
# RADIACAO_GLOBAL_KJ_m2                     23914
# UMIDADE_RELATIVA_DO_AR_HORARIA_%            248
# VENTO_VELOCIDADE_HORARIA_M/S                294
# dtype: int64

# %% [markdown]
# <h3>Problemas a serem resolvidos</h3>
#
# - Pontos vazios
# - dados valores inválidos -9999
# - Dados númericos como str

# %% [markdown]
# ## Tratamentos

# %%
dataset['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C'] = dataset['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C'].str.replace(',', '.').astype(float)
dataset['RADIACAO_GLOBAL_KJ_m2']                  = dataset['RADIACAO_GLOBAL_KJ_m2'].str.replace(',', '.').astype(float)
dataset['VENTO_VELOCIDADE_HORARIA_M/S']           = dataset['VENTO_VELOCIDADE_HORARIA_M/S'].str.replace(',', '.').astype(float)
# Out:
# <ipython-input-11-d8c30489b29d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C'] = dataset['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C'].str.replace(',', '.').astype(float)
# <ipython-input-11-d8c30489b29d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['RADIACAO_GLOBAL_KJ_m2']                  = dataset['RADIACAO_GLOBAL_KJ_m2'].str.replace(',', '.').astype(float)
# <ipython-input-11-d8c30489b29d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['VENTO_VELOCIDADE_HORARIA_M/S']           = dataset['VENTO_VELOCIDADE_HORARIA_M/S'].str.replace(',', '.').astype(float)

# %% [markdown]
# ### Removendo dados inválidos

# %%
dataset = dataset.replace(-9999.0, np.nan)

# %% [markdown]
# ### Removendo outliers dados negativos

# %%
# df['Velocidade do Vento (m/s)'] = df['Velocidade do Vento (m/s)'].apply(lambda x: np.nan if x < 0 else x)

# %%
dataset[dataset['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C'] < 0]
# Out:
# Empty DataFrame
# Columns: [DATA, HORA, TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C, RADIACAO_GLOBAL_KJ_m2, UMIDADE_RELATIVA_DO_AR_HORARIA_%, VENTO_VELOCIDADE_HORARIA_M/S]
# Index: []

# %%
dataset[dataset['UMIDADE_RELATIVA_DO_AR_HORARIA_%'] < 0]
# Out:
# Empty DataFrame
# Columns: [DATA, HORA, TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C, RADIACAO_GLOBAL_KJ_m2, UMIDADE_RELATIVA_DO_AR_HORARIA_%, VENTO_VELOCIDADE_HORARIA_M/S]
# Index: []

# %%
dataset[dataset['VENTO_VELOCIDADE_HORARIA_M/S'] < 0]
# Out:
# Empty DataFrame
# Columns: [DATA, HORA, TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C, RADIACAO_GLOBAL_KJ_m2, UMIDADE_RELATIVA_DO_AR_HORARIA_%, VENTO_VELOCIDADE_HORARIA_M/S]
# Index: []

# %%
dataset.describe()
# Out:
#        TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C  RADIACAO_GLOBAL_KJ_m2  \
# count                           204641.000000           94528.000000
# mean                                19.965591            1210.119407
# std                                  5.704715            1073.503815
# min                                  0.400000               0.000000
# 25%                                 16.100000             225.000000
# 50%                                 20.100000             961.000000
# 75%                                 23.700000            2026.025000
# max                                 40.200000            3999.900000
#
#        UMIDADE_RELATIVA_DO_AR_HORARIA_%  VENTO_VELOCIDADE_HORARIA_M/S
# count                     204634.000000                 203614.000000
# mean                          76.000054                      1.537382
# std                           15.736912                      1.016877
# min                           15.000000                      0.000000
# 25%                           65.000000                      0.800000
# 50%                           79.000000                      1.400000
# 75%                           89.000000                      2.100000
# max                          100.000000                     13.300000

# %%
dataset.isna().sum()
# Out:
# DATA                                           0
# HORA                                           0
# TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C      6703
# RADIACAO_GLOBAL_KJ_m2                     116816
# UMIDADE_RELATIVA_DO_AR_HORARIA_%            6710
# VENTO_VELOCIDADE_HORARIA_M/S                7730
# dtype: int64

# %% [markdown]
# ### Verificando as datas

# %%
dataset['DATA'] = pd.to_datetime(dataset['DATA'])

# %%
dataset['DATA']
# Out:
# 0        2000-09-22
# 1        2000-09-22
# 2        2000-09-22
# 3        2000-09-22
# 4        2000-09-22
#             ...
# 211339   2024-10-31
# 211340   2024-10-31
# 211341   2024-10-31
# 211342   2024-10-31
# 211343   2024-10-31
# Name: DATA, Length: 211344, dtype: datetime64[ns]

# %% [markdown]
# Verificando se a sequencia das datas estão corretas

# %%
start_date = dataset['DATA'].min()
end_date = dataset['DATA'].max()
complete_dates = pd.date_range(start=start_date, end=end_date)

datas_faltantes = complete_dates.difference(dataset['DATA'])

print("Datas faltantes:")
print(datas_faltantes)
# Out:
# Datas faltantes:
# DatetimeIndex([], dtype='datetime64[ns]', freq='D')

# %% [markdown]
# ### Plot

# %%
columns = ['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C',
            'RADIACAO_GLOBAL_KJ_m2',
            'UMIDADE_RELATIVA_DO_AR_HORARIA_%',
            'VENTO_VELOCIDADE_HORARIA_M/S']

for variavel in columns:
    plt.figure(figsize=(20, 5))
    plt.plot(dataset['DATA'], dataset[variavel], marker='o', label=variavel)
    plt.title(f'{variavel} ao longo do tempo')
    plt.xlabel('Data')
    plt.ylabel(variavel)
    plt.grid(True)
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Missing data

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(dataset.isnull(), cbar=False, cmap='viridis', yticklabels=False)
plt.title('Mapa de valores ausentes', fontsize=16)
plt.xlabel('features', fontsize=12)
plt.show()

# %%
missing_data = dataset.isnull().sum()

plt.figure(figsize=(10, 6))
missing_data[missing_data > 0].sort_values(ascending=False).plot(kind='bar', color='salmon')
plt.title('Quantidade de Valores Ausentes por Coluna', fontsize=16)
plt.xlabel('Colunas', fontsize=12)
plt.ylabel('Quantidade de Valores Ausentes', fontsize=12)
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
len(dataset['RADIACAO_GLOBAL_KJ_m2'])
# Out:
# 211344

# %%
radiacao = (dataset['RADIACAO_GLOBAL_KJ_m2'].count() / dataset['RADIACAO_GLOBAL_KJ_m2'].isna().sum()) * 100
temp     = (dataset['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C'].isna().sum() / dataset['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C'].count()) * 100
umidade  = (dataset['UMIDADE_RELATIVA_DO_AR_HORARIA_%'].isna().sum() / dataset['UMIDADE_RELATIVA_DO_AR_HORARIA_%'].count()) * 100
vento    = (dataset['VENTO_VELOCIDADE_HORARIA_M/S'].isna().sum() / dataset['VENTO_VELOCIDADE_HORARIA_M/S'].count()) * 100

print(f'Radiacao: {radiacao:.2f}%')
print(f'TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C: {temp:.2f}%')
print(f'UMIDADE_RELATIVA_DO_AR_HORARIA_%: {umidade:.2f}%')
print(f'VENTO_VELOCIDADE_HORARIA_M/S: {vento:.2f}%')
# Out:
# Radiacao: 80.92%
# TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C: 3.28%
# UMIDADE_RELATIVA_DO_AR_HORARIA_%: 3.28%
# VENTO_VELOCIDADE_HORARIA_M/S: 3.80%

# %%
dataset['DATA']
# Out:
# 0        2000-09-22
# 1        2000-09-22
# 2        2000-09-22
# 3        2000-09-22
# 4        2000-09-22
#             ...
# 211339   2024-10-31
# 211340   2024-10-31
# 211341   2024-10-31
# 211342   2024-10-31
# 211343   2024-10-31
# Name: DATA, Length: 211344, dtype: datetime64[ns]

# %% [markdown]
# ### Remover radiação solar

# %%
dataset.drop('RADIACAO_GLOBAL_KJ_m2', axis=1, inplace=True)

# %% [markdown]
# ### Aplicando interpolação nearest (mais próximo)

# %% [markdown]
# **Algumas horas estão com valores NAN**

# %%
none_values = dataset[dataset.isnull().any(axis=1)]
none_values
# Out:
#              DATA      HORA  TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C  \
# 14     2000-09-22     00:00                                     NaN
# 15     2000-09-22     01:00                                     NaN
# 16     2000-09-22     02:00                                     NaN
# 17     2000-09-22     03:00                                     NaN
# 480    2000-10-12     23:00                                     NaN
# ...           ...       ...                                     ...
# 207229 2024-05-13  0000 UTC                                    19.5
# 207564 2024-05-27  1100 UTC                                     NaN
# 207573 2024-05-27  0900 UTC                                     NaN
# 207574 2024-05-27  1000 UTC                                     NaN
# 210638 2024-10-02  0200 UTC                                     NaN
#
#         UMIDADE_RELATIVA_DO_AR_HORARIA_%  VENTO_VELOCIDADE_HORARIA_M/S
# 14                                   NaN                           NaN
# 15                                   NaN                           NaN
# 16                                   NaN                           NaN
# 17                                   NaN                           NaN
# 480                                  NaN                           NaN
# ...                                  ...                           ...
# 207229                              97.0                           NaN
# 207564                               NaN                           NaN
# 207573                               NaN                           NaN
# 207574                               NaN                           NaN
# 210638                               NaN                           NaN
#
# [7747 rows x 5 columns]

# %%
none_values.head(10)
# Out:
#           DATA   HORA  TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C  \
# 14  2000-09-22  00:00                                     NaN
# 15  2000-09-22  01:00                                     NaN
# 16  2000-09-22  02:00                                     NaN
# 17  2000-09-22  03:00                                     NaN
# 480 2000-10-12  23:00                                     NaN
# 481 2000-10-12  22:00                                     NaN
# 482 2000-10-12  21:00                                     NaN
# 483 2000-10-12  20:00                                     NaN
# 484 2000-10-12  19:00                                     NaN
# 485 2000-10-12  18:00                                     NaN
#
#      UMIDADE_RELATIVA_DO_AR_HORARIA_%  VENTO_VELOCIDADE_HORARIA_M/S
# 14                                NaN                           NaN
# 15                                NaN                           NaN
# 16                                NaN                           NaN
# 17                                NaN                           NaN
# 480                               NaN                           NaN
# 481                               NaN                           NaN
# 482                               NaN                           NaN
# 483                               NaN                           NaN
# 484                               NaN                           NaN
# 485                               NaN                           NaN

# %%
dataset.head(10)
# Out:
#         DATA   HORA  TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C  \
# 0 2000-09-22  22:00                                    15.7
# 1 2000-09-22  21:00                                    17.8
# 2 2000-09-22  20:00                                    19.8
# 3 2000-09-22  19:00                                    20.9
# 4 2000-09-22  18:00                                    20.9
# 5 2000-09-22  17:00                                    20.9
# 6 2000-09-22  16:00                                    19.8
# 7 2000-09-22  15:00                                    19.5
# 8 2000-09-22  14:00                                    18.6
# 9 2000-09-22  13:00                                    17.9
#
#    UMIDADE_RELATIVA_DO_AR_HORARIA_%  VENTO_VELOCIDADE_HORARIA_M/S
# 0                              68.0                           2.4
# 1                              63.0                           2.2
# 2                              52.0                           1.7
# 3                              42.0                           1.7
# 4                              40.0                           1.1
# 5                              44.0                           1.7
# 6                              45.0                           1.2
# 7                              45.0                           1.7
# 8                              49.0                           1.6
# 9                              62.0                           2.3

# %%
np.mean(dataset['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C']), np.mean(dataset['UMIDADE_RELATIVA_DO_AR_HORARIA_%']), np.mean(dataset['VENTO_VELOCIDADE_HORARIA_M/S'])
# Out:
# (19.965590961732985, 76.00005375450804, 1.5373824982565047)

# %%
dataset['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C'] = dataset['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C'].interpolate(method="nearest")
dataset['UMIDADE_RELATIVA_DO_AR_HORARIA_%']       = dataset['UMIDADE_RELATIVA_DO_AR_HORARIA_%'].interpolate(method="nearest")
dataset['VENTO_VELOCIDADE_HORARIA_M/S']           = dataset['VENTO_VELOCIDADE_HORARIA_M/S'].interpolate(method="nearest")

# %%
dataset.isna().sum()
# Out:
# DATA                                      0
# HORA                                      0
# TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C    0
# UMIDADE_RELATIVA_DO_AR_HORARIA_%          0
# VENTO_VELOCIDADE_HORARIA_M/S              0
# dtype: int64

# %%
np.mean(dataset['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C']), np.mean(dataset['UMIDADE_RELATIVA_DO_AR_HORARIA_%']), np.mean(dataset['VENTO_VELOCIDADE_HORARIA_M/S'])
# Out:
# (19.939770232417292, 75.96847320009084, 1.5430653342418044)

# %% [markdown]
# ## Agrupando dados em dados diários

# %%
dataset.head(23)
# Out:
#          DATA   HORA  TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C  \
# 0  2000-09-22  22:00                                    15.7
# 1  2000-09-22  21:00                                    17.8
# 2  2000-09-22  20:00                                    19.8
# 3  2000-09-22  19:00                                    20.9
# 4  2000-09-22  18:00                                    20.9
# 5  2000-09-22  17:00                                    20.9
# 6  2000-09-22  16:00                                    19.8
# 7  2000-09-22  15:00                                    19.5
# 8  2000-09-22  14:00                                    18.6
# 9  2000-09-22  13:00                                    17.9
# 10 2000-09-22  12:00                                    16.6
# 11 2000-09-22  11:00                                    15.3
# 12 2000-09-22  23:00                                    14.7
# 13 2000-09-22  09:00                                    14.4
# 14 2000-09-22  00:00                                    14.4
# 15 2000-09-22  01:00                                    14.4
# 16 2000-09-22  02:00                                    14.4
# 17 2000-09-22  03:00                                    14.4
# 18 2000-09-22  10:00                                    14.4
# 19 2000-09-22  05:00                                    15.3
# 20 2000-09-22  06:00                                    15.1
# 21 2000-09-22  07:00                                    14.8
# 22 2000-09-22  08:00                                    14.5
#
#     UMIDADE_RELATIVA_DO_AR_HORARIA_%  VENTO_VELOCIDADE_HORARIA_M/S
# 0                               68.0                           2.4
# 1                               63.0                           2.2
# 2                               52.0                           1.7
# 3                               42.0                           1.7
# 4                               40.0                           1.1
# 5                               44.0                           1.7
# 6                               45.0                           1.2
# 7                               45.0                           1.7
# 8                               49.0                           1.6
# 9                               62.0                           2.3
# 10                              76.0                           2.2
# 11                              84.0                           2.2
# 12                              70.0                           2.6
# 13                              85.0                           1.7
# 14                              85.0                           1.7
# 15                              85.0                           1.7
# 16                              86.0                           1.8
# 17                              86.0                           1.8
# 18                              86.0                           1.8
# 19                              95.0                           2.2
# 20                              94.0                           1.9
# 21                              95.0                           1.5
# 22                              94.0                           1.7

# %%
df_sorted = dataset.sort_values(
    by=["DATA", "TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C", "UMIDADE_RELATIVA_DO_AR_HORARIA_%"],
    ascending=[True, False, False]
)

grouped_df = df_sorted.groupby("DATA").first().reset_index()
grouped_df.head(5)
# Out:
#         DATA   HORA  TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C  \
# 0 2000-09-22  17:00                                    20.9
# 1 2000-09-23  17:00                                    26.9
# 2 2000-09-24  02:00                                    18.7
# 3 2000-09-25  19:00                                    14.8
# 4 2000-09-26  17:00                                    17.1
#
#    UMIDADE_RELATIVA_DO_AR_HORARIA_%  VENTO_VELOCIDADE_HORARIA_M/S
# 0                              44.0                           1.7
# 1                              49.0                           0.7
# 2                              97.0                           0.5
# 3                              39.0                           2.4
# 4                              39.0                           2.2

# %%
grouped_df
# Out:
#            DATA      HORA  TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C  \
# 0    2000-09-22     17:00                                    20.9
# 1    2000-09-23     17:00                                    26.9
# 2    2000-09-24     02:00                                    18.7
# 3    2000-09-25     19:00                                    14.8
# 4    2000-09-26     17:00                                    17.1
# ...         ...       ...                                     ...
# 8801 2024-10-27  1800 UTC                                    24.9
# 8802 2024-10-28  1700 UTC                                    28.0
# 8803 2024-10-29  1800 UTC                                    28.9
# 8804 2024-10-30  1700 UTC                                    28.0
# 8805 2024-10-31  1600 UTC                                    30.7
#
#       UMIDADE_RELATIVA_DO_AR_HORARIA_%  VENTO_VELOCIDADE_HORARIA_M/S
# 0                                 44.0                           1.7
# 1                                 49.0                           0.7
# 2                                 97.0                           0.5
# 3                                 39.0                           2.4
# 4                                 39.0                           2.2
# ...                                ...                           ...
# 8801                              31.0                           1.8
# 8802                              52.0                           1.4
# 8803                              58.0                           1.6
# 8804                              58.0                           3.3
# 8805                              51.0                           1.8
#
# [8806 rows x 5 columns]

# %% [markdown]
# ## Feature engineering

# %%
from metpy.calc import heat_index
from metpy.units import units

# %% [markdown]
# ### Convertendo TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C para Fahrenheit

# %% [markdown]
# ### Criando feature HI (NWS)
# https://www.wpc.ncep.noaa.gov/html/heatindex.shtml

# %%
# Converter Celsius para Fahrenheit
temperature_fahrenheit = grouped_df['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C'].values * 9/5 + 32

# aplicando a unidade de medida
temperature_fahrenheit = temperature_fahrenheit * units.degF
relative_humidity = grouped_df['UMIDADE_RELATIVA_DO_AR_HORARIA_%'].values * units.percent

# Calcular o Heat Index (em Fahrenheit)
heat_index_fahrenheit = heat_index(temperature_fahrenheit, relative_humidity)

# Converter o resultado de volta para Celsius
grouped_df['heat_index_f'] = heat_index_fahrenheit.round(2)
grouped_df['heat_index'] = ((grouped_df['heat_index_f'].values - 32) * 5/9).round(2)

print(f"Heat Index (HI) em Celsius: {grouped_df['heat_index']}\n\n")
print(f"Heat Index (HI) em fahrenheit: {grouped_df['heat_index_f']}")
# Out:
# Heat Index (HI) em Celsius: 0       20.19
# 1       27.27
# 2       19.16
# 3       13.36
# 4       15.88
#         ...
# 8801    24.26
# 8802    28.63
# 8803    30.57
# 8804    29.23
# 8805    32.32
# Name: heat_index, Length: 8806, dtype: float64
#
#
# Heat Index (HI) em fahrenheit: 0       68.35
# 1       81.08
# 2       66.48
# 3       56.04
# 4       60.59
#         ...
# 8801    75.66
# 8802    83.54
# 8803    87.03
# 8804    84.62
# 8805    90.17
# Name: heat_index_f, Length: 8806, dtype: float64

# %% [markdown]
# #### Test

# %%
num = 2

# %%
grouped_df['UMIDADE_RELATIVA_DO_AR_HORARIA_%'][num]
# Out:
# 97.0

# %%
grouped_df['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C'][num]
# Out:
# 18.7

# %%
(grouped_df['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C'].values * 9/5 + 32)[num]
# Out:
# 65.66

# %%
grouped_df['heat_index_f'][num]
# Out:
# 66.48

# %%
grouped_df['heat_index'][num]
# Out:
# 19.16

# %%
grouped_df
# Out:
#            DATA      HORA  TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C  \
# 0    2000-09-22     17:00                                    20.9
# 1    2000-09-23     17:00                                    26.9
# 2    2000-09-24     02:00                                    18.7
# 3    2000-09-25     19:00                                    14.8
# 4    2000-09-26     17:00                                    17.1
# ...         ...       ...                                     ...
# 8801 2024-10-27  1800 UTC                                    24.9
# 8802 2024-10-28  1700 UTC                                    28.0
# 8803 2024-10-29  1800 UTC                                    28.9
# 8804 2024-10-30  1700 UTC                                    28.0
# 8805 2024-10-31  1600 UTC                                    30.7
#
#       UMIDADE_RELATIVA_DO_AR_HORARIA_%  VENTO_VELOCIDADE_HORARIA_M/S  \
# 0                                 44.0                           1.7
# 1                                 49.0                           0.7
# 2                                 97.0                           0.5
# 3                                 39.0                           2.4
# 4                                 39.0                           2.2
# ...                                ...                           ...
# 8801                              31.0                           1.8
# 8802                              52.0                           1.4
# 8803                              58.0                           1.6
# 8804                              58.0                           3.3
# 8805                              51.0                           1.8
#
#       heat_index_f  heat_index
# 0            68.35       20.19
# 1            81.08       27.27
# 2            66.48       19.16
# 3            56.04       13.36
# 4            60.59       15.88
# ...            ...         ...
# 8801         75.66       24.26
# 8802         83.54       28.63
# 8803         87.03       30.57
# 8804         84.62       29.23
# 8805         90.17       32.32
#
# [8806 rows x 7 columns]

# %%
grouped_df[grouped_df['heat_index'] > 37.2]
# Out:
#            DATA      HORA  TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C  \
# 78   2000-12-09     16:00                                    34.6
# 82   2000-12-13     17:00                                    33.7
# 95   2000-12-26     20:00                                    35.4
# 96   2000-12-27     14:00                                    34.3
# 105  2001-01-05     16:00                                    35.4
# ...         ...       ...                                     ...
# 8555 2024-02-24  1600 UTC                                    32.5
# 8573 2024-03-13  1700 UTC                                    33.4
# 8574 2024-03-14  1700 UTC                                    35.6
# 8578 2024-03-18  1800 UTC                                    34.2
# 8580 2024-03-20  1900 UTC                                    36.1
#
#       UMIDADE_RELATIVA_DO_AR_HORARIA_%  VENTO_VELOCIDADE_HORARIA_M/S  \
# 78                                44.0                           1.9
# 82                                49.0                           0.5
# 95                                42.0                           2.0
# 96                                48.0                           4.1
# 105                               45.0                           2.7
# ...                                ...                           ...
# 8555                              58.0                           1.7
# 8573                              54.0                           1.2
# 8574                              40.0                           1.2
# 8578                              53.0                           0.9
# 8580                              45.0                           1.6
#
#       heat_index_f  heat_index
# 78           99.83       37.68
# 82           99.37       37.43
# 95          101.53       38.63
# 96          101.06       38.37
# 105         103.43       39.68
# ...            ...         ...
# 8555         99.72       37.62
# 8573        101.11       38.39
# 8574        101.04       38.36
# 8578        103.85       39.92
# 8580        106.23       41.24
#
# [350 rows x 7 columns]

# %% [markdown]
# ### HI média mensal

# %%
grouped_df['DATA'].dt.to_period('M')
# Out:
# 0       2000-09
# 1       2000-09
# 2       2000-09
# 3       2000-09
# 4       2000-09
#          ...
# 8801    2024-10
# 8802    2024-10
# 8803    2024-10
# 8804    2024-10
# 8805    2024-10
# Name: DATA, Length: 8806, dtype: period[M]

# %%
grouped_df['month'] = grouped_df['DATA'].dt.to_period('M')

monthly_df = grouped_df.groupby('month')['heat_index'].mean().reset_index()

monthly_df
# Out:
#        month  heat_index
# 0    2000-09   21.801111
# 1    2000-10   23.427742
# 2    2000-11   26.305667
# 3    2000-12   30.079677
# 4    2001-01   31.907742
# ..       ...         ...
# 285  2024-06   22.028667
# 286  2024-07   17.503548
# 287  2024-08   20.590000
# 288  2024-09   24.021000
# 289  2024-10   26.017742
#
# [290 rows x 2 columns]

# %% [markdown]
# #### Desvio padrão

# %%
standard_deviation = grouped_df.groupby('month')['heat_index'].std().reset_index()
monthly_df['standard_deviation'] = standard_deviation['heat_index']

monthly_df
# Out:
#        month  heat_index  standard_deviation
# 0    2000-09   21.801111            5.031489
# 1    2000-10   23.427742            3.864828
# 2    2000-11   26.305667            4.183658
# 3    2000-12   30.079677            4.615565
# 4    2001-01   31.907742            4.864888
# ..       ...         ...                 ...
# 285  2024-06   22.028667            5.929766
# 286  2024-07   17.503548            5.561158
# 287  2024-08   20.590000            5.447565
# 288  2024-09   24.021000            4.649160
# 289  2024-10   26.017742            4.499940
#
# [290 rows x 3 columns]

# %% [markdown]
# #### Temperatura média, Humidade média e Média da Velocidade do vento

# %%
monthly_mean = grouped_df.groupby('month').agg({
    'TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C': 'mean',
    'UMIDADE_RELATIVA_DO_AR_HORARIA_%': 'mean',
    'VENTO_VELOCIDADE_HORARIA_M/S': 'mean'
}).reset_index()

# Arredondando os resultados para 2 casas decimais
monthly_mean = monthly_mean.round(2)

monthly_df['mean_temperature'] = monthly_mean['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C']
monthly_df['mean_humidity'] = monthly_mean['UMIDADE_RELATIVA_DO_AR_HORARIA_%']
monthly_df['mean_wind_speed'] = monthly_mean['VENTO_VELOCIDADE_HORARIA_M/S']

monthly_df
# Out:
#        month  heat_index  standard_deviation  mean_temperature  mean_humidity  \
# 0    2000-09   21.801111            5.031489             22.08          51.78
# 1    2000-10   23.427742            3.864828             23.24          62.81
# 2    2000-11   26.305667            4.183658             26.29          51.73
# 3    2000-12   30.079677            4.615565             28.94          51.32
# 4    2001-01   31.907742            4.864888             29.69          59.10
# ..       ...         ...                 ...               ...            ...
# 285  2024-06   22.028667            5.929766             21.99          64.67
# 286  2024-07   17.503548            5.561158             17.91          67.87
# 287  2024-08   20.590000            5.447565             20.85          60.29
# 288  2024-09   24.021000            4.649160             23.80          63.00
# 289  2024-10   26.017742            4.499940             25.51          57.48
#
#      mean_wind_speed
# 0               1.47
# 1               2.75
# 2               2.28
# 3               2.00
# 4               2.19
# ..               ...
# 285             1.66
# 286             1.31
# 287             1.61
# 288             1.42
# 289             1.90
#
# [290 rows x 6 columns]

# %% [markdown]
# #### Temperatura Máxima e Mínima

# %%
max_temp = grouped_df.groupby('month')['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C'].max().reset_index()
min_temp = grouped_df.groupby('month')['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C'].min().reset_index()

monthly_df['max_temperature'] = max_temp['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C']
monthly_df['min_temperature'] = min_temp['TEMPERATURA_DO_AR_BULBO_SECO_HORARIA_C']

monthly_df
# Out:
#        month  heat_index  standard_deviation  mean_temperature  mean_humidity  \
# 0    2000-09   21.801111            5.031489             22.08          51.78
# 1    2000-10   23.427742            3.864828             23.24          62.81
# 2    2000-11   26.305667            4.183658             26.29          51.73
# 3    2000-12   30.079677            4.615565             28.94          51.32
# 4    2001-01   31.907742            4.864888             29.69          59.10
# ..       ...         ...                 ...               ...            ...
# 285  2024-06   22.028667            5.929766             21.99          64.67
# 286  2024-07   17.503548            5.561158             17.91          67.87
# 287  2024-08   20.590000            5.447565             20.85          60.29
# 288  2024-09   24.021000            4.649160             23.80          63.00
# 289  2024-10   26.017742            4.499940             25.51          57.48
#
#      mean_wind_speed  max_temperature  min_temperature
# 0               1.47             26.9             14.8
# 1               2.75             31.2             18.6
# 2               2.28             35.5             20.7
# 3               2.00             35.4             22.2
# 4               2.19             35.4             21.4
# ..               ...              ...              ...
# 285             1.66             31.5             11.6
# 286             1.31             28.9              9.8
# 287             1.61             31.1             12.5
# 288             1.42             33.7             18.0
# 289             1.90             33.6             19.3
#
# [290 rows x 8 columns]

# %% [markdown]
# #### Soma HI

# %%
sum_heat_index = grouped_df.groupby('month')['heat_index'].sum().reset_index()

monthly_df['sum_heat_index'] = sum_heat_index['heat_index']

monthly_df
# Out:
#        month  heat_index  standard_deviation  mean_temperature  mean_humidity  \
# 0    2000-09   21.801111            5.031489             22.08          51.78
# 1    2000-10   23.427742            3.864828             23.24          62.81
# 2    2000-11   26.305667            4.183658             26.29          51.73
# 3    2000-12   30.079677            4.615565             28.94          51.32
# 4    2001-01   31.907742            4.864888             29.69          59.10
# ..       ...         ...                 ...               ...            ...
# 285  2024-06   22.028667            5.929766             21.99          64.67
# 286  2024-07   17.503548            5.561158             17.91          67.87
# 287  2024-08   20.590000            5.447565             20.85          60.29
# 288  2024-09   24.021000            4.649160             23.80          63.00
# 289  2024-10   26.017742            4.499940             25.51          57.48
#
#      mean_wind_speed  max_temperature  min_temperature  sum_heat_index
# 0               1.47             26.9             14.8          196.21
# 1               2.75             31.2             18.6          726.26
# 2               2.28             35.5             20.7          789.17
# 3               2.00             35.4             22.2          932.47
# 4               2.19             35.4             21.4          989.14
# ..               ...              ...              ...             ...
# 285             1.66             31.5             11.6          660.86
# 286             1.31             28.9              9.8          542.61
# 287             1.61             31.1             12.5          638.29
# 288             1.42             33.7             18.0          720.63
# 289             1.90             33.6             19.3          806.55
#
# [290 rows x 9 columns]

# %% [markdown]
# #### Percentil 95 e 99

# %%
percentil_95 = grouped_df.groupby('month')['heat_index'].apply(lambda x: np.percentile(x, 95)).reset_index()
percentil_99 = grouped_df.groupby('month')['heat_index'].apply(lambda x: np.percentile(x, 99)).reset_index()

monthly_df['percentil_95'] = percentil_95['heat_index']
monthly_df['percentil_99'] = percentil_99['heat_index']

monthly_df
# Out:
#        month  heat_index  standard_deviation  mean_temperature  mean_humidity  \
# 0    2000-09   21.801111            5.031489             22.08          51.78
# 1    2000-10   23.427742            3.864828             23.24          62.81
# 2    2000-11   26.305667            4.183658             26.29          51.73
# 3    2000-12   30.079677            4.615565             28.94          51.32
# 4    2001-01   31.907742            4.864888             29.69          59.10
# ..       ...         ...                 ...               ...            ...
# 285  2024-06   22.028667            5.929766             21.99          64.67
# 286  2024-07   17.503548            5.561158             17.91          67.87
# 287  2024-08   20.590000            5.447565             20.85          60.29
# 288  2024-09   24.021000            4.649160             23.80          63.00
# 289  2024-10   26.017742            4.499940             25.51          57.48
#
#      mean_wind_speed  max_temperature  min_temperature  sum_heat_index  \
# 0               1.47             26.9             14.8          196.21
# 1               2.75             31.2             18.6          726.26
# 2               2.28             35.5             20.7          789.17
# 3               2.00             35.4             22.2          932.47
# 4               2.19             35.4             21.4          989.14
# ..               ...              ...              ...             ...
# 285             1.66             31.5             11.6          660.86
# 286             1.31             28.9              9.8          542.61
# 287             1.61             31.1             12.5          638.29
# 288             1.42             33.7             18.0          720.63
# 289             1.90             33.6             19.3          806.55
#
#      percentil_95  percentil_99
# 0         27.0500       27.2260
# 1         29.0850       32.0680
# 2         33.1225       34.4538
# 3         38.0250       38.5520
# 4         38.7800       39.5900
# ..            ...           ...
# 285       30.3440       30.7398
# 286       26.9700       28.2240
# 287       29.7250       30.2380
# 288       33.1130       34.3050
# 289       33.9050       35.8910
#
# [290 rows x 11 columns]

# %% [markdown]
# ### LAGS

# %%
monthly_df['lag_heat_index_1'] = monthly_df['heat_index'].shift(1)
monthly_df['lag_heat_index_2'] = monthly_df['heat_index'].shift(2)
monthly_df['lag_heat_index_3'] = monthly_df['heat_index'].shift(3)

monthly_df.dropna(inplace=True)

monthly_df
# Out:
#        month  heat_index  standard_deviation  mean_temperature  mean_humidity  \
# 3    2000-12   30.079677            4.615565             28.94          51.32
# 4    2001-01   31.907742            4.864888             29.69          59.10
# 5    2001-02   32.959643            3.889432             30.08          60.14
# 6    2001-03   32.071290            3.585808             29.82          56.61
# 7    2001-04   25.963667            3.307106             25.37          64.77
# ..       ...         ...                 ...               ...            ...
# 285  2024-06   22.028667            5.929766             21.99          64.67
# 286  2024-07   17.503548            5.561158             17.91          67.87
# 287  2024-08   20.590000            5.447565             20.85          60.29
# 288  2024-09   24.021000            4.649160             23.80          63.00
# 289  2024-10   26.017742            4.499940             25.51          57.48
#
#      mean_wind_speed  max_temperature  min_temperature  sum_heat_index  \
# 3               2.00             35.4             22.2          932.47
# 4               2.19             35.4             21.4          989.14
# 5               2.33             34.2             23.5          922.87
# 6               2.21             34.4             25.1          994.21
# 7               1.68             30.8             19.3          778.91
# ..               ...              ...              ...             ...
# 285             1.66             31.5             11.6          660.86
# 286             1.31             28.9              9.8          542.61
# 287             1.61             31.1             12.5          638.29
# 288             1.42             33.7             18.0          720.63
# 289             1.90             33.6             19.3          806.55
#
#      percentil_95  percentil_99  lag_heat_index_1  lag_heat_index_2  \
# 3          38.025       38.5520         26.305667         23.427742
# 4          38.780       39.5900         30.079677         26.305667
# 5          38.625       38.8030         31.907742         30.079677
# 6          37.065       37.7400         32.959643         31.907742
# 7          30.751       32.1117         32.071290         32.959643
# ..            ...           ...               ...               ...
# 285        30.344       30.7398         20.278710         26.315000
# 286        26.970       28.2240         22.028667         20.278710
# 287        29.725       30.2380         17.503548         22.028667
# 288        33.113       34.3050         20.590000         17.503548
# 289        33.905       35.8910         24.021000         20.590000
#
#      lag_heat_index_3
# 3           21.801111
# 4           23.427742
# 5           26.305667
# 6           30.079677
# 7           31.907742
# ..                ...
# 285         32.049032
# 286         26.315000
# 287         20.278710
# 288         22.028667
# 289         17.503548
#
# [287 rows x 14 columns]

# %% [markdown]
# ## Salvando Dataset

# %%
monthly_df.rename(columns={'month': 'date'}, inplace=True)

# %%
monthly_df.to_csv('monthly_df.csv', index=False)

# %%
monthly_df
# Out:
#         date  heat_index  standard_deviation  mean_temperature  mean_humidity  \
# 3    2000-12   30.079677            4.615565             28.94          51.32
# 4    2001-01   31.907742            4.864888             29.69          59.10
# 5    2001-02   32.959643            3.889432             30.08          60.14
# 6    2001-03   32.071290            3.585808             29.82          56.61
# 7    2001-04   25.963667            3.307106             25.37          64.77
# ..       ...         ...                 ...               ...            ...
# 285  2024-06   22.028667            5.929766             21.99          64.67
# 286  2024-07   17.503548            5.561158             17.91          67.87
# 287  2024-08   20.590000            5.447565             20.85          60.29
# 288  2024-09   24.021000            4.649160             23.80          63.00
# 289  2024-10   26.017742            4.499940             25.51          57.48
#
#      mean_wind_speed  max_temperature  min_temperature  sum_heat_index  \
# 3               2.00             35.4             22.2          932.47
# 4               2.19             35.4             21.4          989.14
# 5               2.33             34.2             23.5          922.87
# 6               2.21             34.4             25.1          994.21
# 7               1.68             30.8             19.3          778.91
# ..               ...              ...              ...             ...
# 285             1.66             31.5             11.6          660.86
# 286             1.31             28.9              9.8          542.61
# 287             1.61             31.1             12.5          638.29
# 288             1.42             33.7             18.0          720.63
# 289             1.90             33.6             19.3          806.55
#
#      percentil_95  percentil_99  lag_heat_index_1  lag_heat_index_2  \
# 3          38.025       38.5520         26.305667         23.427742
# 4          38.780       39.5900         30.079677         26.305667
# 5          38.625       38.8030         31.907742         30.079677
# 6          37.065       37.7400         32.959643         31.907742
# 7          30.751       32.1117         32.071290         32.959643
# ..            ...           ...               ...               ...
# 285        30.344       30.7398         20.278710         26.315000
# 286        26.970       28.2240         22.028667         20.278710
# 287        29.725       30.2380         17.503548         22.028667
# 288        33.113       34.3050         20.590000         17.503548
# 289        33.905       35.8910         24.021000         20.590000
#
#      lag_heat_index_3
# 3           21.801111
# 4           23.427742
# 5           26.305667
# 6           30.079677
# 7           31.907742
# ..                ...
# 285         32.049032
# 286         26.315000
# 287         20.278710
# 288         22.028667
# 289         17.503548
#
# [287 rows x 14 columns]

# %% [markdown]
# #### Plot

# %%
monthly_df['date'] = monthly_df['date'].dt.to_timestamp()

# %%
columns = ['heat_index',
            'standard_deviation',
            'max_temperature',
            'min_temperature',
            'percentil_99',
            'percentil_95',
            'sum_heat_index']

for variavel in columns:
    plt.figure(figsize=(20, 5))
    plt.plot(monthly_df['date'], monthly_df[variavel], marker='o', label=variavel)
    plt.title(f'{variavel} ao longo do tempo')
    plt.xlabel('Data')
    plt.ylabel(variavel)
    plt.grid(True)
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Pré-processamento DATASUS

# %%
# csv_url = 'https://raw.githubusercontent.com/ThierrryScotto/trabalho_pratico/refs/heads/main/datasus.csv'
# csv_url = 'https://raw.githubusercontent.com/ThierrryScotto/trabalho_pratico/refs/heads/main/datasets/datasus_por_local_internacao_.csv'
csv_url = 'https://raw.githubusercontent.com/ThierrryScotto/trabalho_pratico/refs/heads/main/datasets/datasus_por_local_intercacao_v2.csv'

datasus_df = pd.read_csv(csv_url, sep=';')

datasus_df
# Out:
#     Ano/mes processamento  Internacoes Media_Permanencia  Obitos  \
# 0          ..Janeiro/1998         3905               6,3     229
# 1        ..Fevereiro/1998         3502               5,8     200
# 2            ..Marco/1998         4322               6,0     221
# 3            ..Abril/1998         4132               6,0     236
# 4             ..Maio/1998         4434               6,0     261
# ..                    ...          ...               ...     ...
# 316             Maio/2024         3172               6,7     313
# 317            Junho/2024         3640               6,6     329
# 318            Julho/2024         3689               6,5     338
# 319           Agosto/2024         3846               6,8     389
# 320         Setembro/2024         3426               6,9     298
#
#     Taxa_Mortalidade
# 0               5,86
# 1               5,71
# 2               5,11
# 3               5,71
# 4               5,89
# ..               ...
# 316             9,87
# 317             9,04
# 318             9,16
# 319            10,11
# 320             8,70
#
# [321 rows x 5 columns]

# %%
datasus_df.rename(columns={
    'Ano/mes processamento': 'date',
    'Internacoes': 'hospitalizations',
    'Media_Permanencia': "average_stay",
    'Obitos': 'deaths',
    'Taxa_Mortalidade': 'mortality_rate'
    }, inplace=True)

datasus_df
# Out:
#                  date  hospitalizations average_stay  deaths mortality_rate
# 0      ..Janeiro/1998              3905          6,3     229           5,86
# 1    ..Fevereiro/1998              3502          5,8     200           5,71
# 2        ..Marco/1998              4322          6,0     221           5,11
# 3        ..Abril/1998              4132          6,0     236           5,71
# 4         ..Maio/1998              4434          6,0     261           5,89
# ..                ...               ...          ...     ...            ...
# 316         Maio/2024              3172          6,7     313           9,87
# 317        Junho/2024              3640          6,6     329           9,04
# 318        Julho/2024              3689          6,5     338           9,16
# 319       Agosto/2024              3846          6,8     389          10,11
# 320     Setembro/2024              3426          6,9     298           8,70
#
# [321 rows x 5 columns]

# %% [markdown]
# ## Ajustando a data

# %%
datasus_df['date'] = datasus_df['date'].str.lstrip('.')
datasus_df['date'] = datasus_df['date'].str.replace(' ', '').str.strip()

datasus_df
# Out:
#                date  hospitalizations average_stay  deaths mortality_rate
# 0      Janeiro/1998              3905          6,3     229           5,86
# 1    Fevereiro/1998              3502          5,8     200           5,71
# 2        Marco/1998              4322          6,0     221           5,11
# 3        Abril/1998              4132          6,0     236           5,71
# 4         Maio/1998              4434          6,0     261           5,89
# ..              ...               ...          ...     ...            ...
# 316       Maio/2024              3172          6,7     313           9,87
# 317      Junho/2024              3640          6,6     329           9,04
# 318      Julho/2024              3689          6,5     338           9,16
# 319     Agosto/2024              3846          6,8     389          10,11
# 320   Setembro/2024              3426          6,9     298           8,70
#
# [321 rows x 5 columns]

# %%
datasus_df['date']
# Out:
# 0        Janeiro/1998
# 1      Fevereiro/1998
# 2          Marco/1998
# 3          Abril/1998
# 4           Maio/1998
#             ...
# 316         Maio/2024
# 317        Junho/2024
# 318        Julho/2024
# 319       Agosto/2024
# 320     Setembro/2024
# Name: date, Length: 321, dtype: object

# %%
months = {
    'Janeiro': '01', 'Fevereiro': '02', 'Marco': '03', 'Abril': '04',
    'Maio': '05', 'Junho': '06', 'Julho': '07', 'Agosto': '08',
    'Setembro': '09', 'Outubro': '10', 'Novembro': '11', 'Dezembro': '12'
}

datasus_df['date'] = datasus_df['date'].replace(months, regex=True)
datasus_df['date'] = datasus_df['date'].apply(lambda x: '-'.join(x.split('/')[::-1]))
datasus_df['date'] = pd.to_datetime(datasus_df['date'], format='%Y-%m')

datasus_df
# Out:
#           date  hospitalizations average_stay  deaths mortality_rate
# 0   1998-01-01              3905          6,3     229           5,86
# 1   1998-02-01              3502          5,8     200           5,71
# 2   1998-03-01              4322          6,0     221           5,11
# 3   1998-04-01              4132          6,0     236           5,71
# 4   1998-05-01              4434          6,0     261           5,89
# ..         ...               ...          ...     ...            ...
# 316 2024-05-01              3172          6,7     313           9,87
# 317 2024-06-01              3640          6,6     329           9,04
# 318 2024-07-01              3689          6,5     338           9,16
# 319 2024-08-01              3846          6,8     389          10,11
# 320 2024-09-01              3426          6,9     298           8,70
#
# [321 rows x 5 columns]

# %%
datasus_df
# Out:
#           date  hospitalizations average_stay  deaths mortality_rate
# 0   1998-01-01              3905          6,3     229           5,86
# 1   1998-02-01              3502          5,8     200           5,71
# 2   1998-03-01              4322          6,0     221           5,11
# 3   1998-04-01              4132          6,0     236           5,71
# 4   1998-05-01              4434          6,0     261           5,89
# ..         ...               ...          ...     ...            ...
# 316 2024-05-01              3172          6,7     313           9,87
# 317 2024-06-01              3640          6,6     329           9,04
# 318 2024-07-01              3689          6,5     338           9,16
# 319 2024-08-01              3846          6,8     389          10,11
# 320 2024-09-01              3426          6,9     298           8,70
#
# [321 rows x 5 columns]

# %% [markdown]
# ## Verificando as datas

# %%
start_date = datasus_df["date"].min()
end_date = datasus_df["date"].max()
expected_dates = pd.date_range(start=start_date, end=end_date, freq="MS")

missing_dates = expected_dates.difference(datasus_df["date"])

if missing_dates.empty:
    print("Datas corretas")
else:
    print("Datas ausentes ou fora de ordem detectadas:")
    print(missing_dates)
# Out:
# Datas corretas

# %% [markdown]
# ## Analise dos dados

# %%
datasus_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              321 non-null    datetime64[ns]
#  1   hospitalizations  321 non-null    int64
#  2   average_stay      321 non-null    object
#  3   deaths            321 non-null    int64
#  4   mortality_rate    321 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 12.7+ KB

# %%
datasus_df.describe()
# Out:
#                                 date  hospitalizations      deaths
# count                            321        321.000000  321.000000
# mean   2011-05-02 03:57:45.420560640       3597.043614  291.931464
# min              1998-01-01 00:00:00       2196.000000  141.000000
# 25%              2004-09-01 00:00:00       3285.000000  259.000000
# 50%              2011-05-01 00:00:00       3523.000000  286.000000
# 75%              2018-01-01 00:00:00       3959.000000  323.000000
# max              2024-09-01 00:00:00       4768.000000  431.000000
# std                              NaN        448.462190   45.881386

# %% [markdown]
# ### Convertendo para float cases e average_stay

# %%
datasus_df['average_stay'] = datasus_df['average_stay'].str.replace(',', '.').astype(float)
datasus_df['mortality_rate'] = datasus_df['mortality_rate'].str.replace(',', '.').astype(float)

datasus_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              321 non-null    datetime64[ns]
#  1   hospitalizations  321 non-null    int64
#  2   average_stay      321 non-null    float64
#  3   deaths            321 non-null    int64
#  4   mortality_rate    321 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 12.7 KB

# %%
datasus_df
# Out:
#           date  hospitalizations  average_stay  deaths  mortality_rate
# 0   1998-01-01              3905           6.3     229            5.86
# 1   1998-02-01              3502           5.8     200            5.71
# 2   1998-03-01              4322           6.0     221            5.11
# 3   1998-04-01              4132           6.0     236            5.71
# 4   1998-05-01              4434           6.0     261            5.89
# ..         ...               ...           ...     ...             ...
# 316 2024-05-01              3172           6.7     313            9.87
# 317 2024-06-01              3640           6.6     329            9.04
# 318 2024-07-01              3689           6.5     338            9.16
# 319 2024-08-01              3846           6.8     389           10.11
# 320 2024-09-01              3426           6.9     298            8.70
#
# [321 rows x 5 columns]

# %% [markdown]
# ## Missing data

# %%
datasus_df.isnull().sum()
# Out:
# date                0
# hospitalizations    0
# average_stay        0
# deaths              0
# mortality_rate      0
# dtype: int64

# %% [markdown]
# ## Valores inválidos

# %%
features = datasus_df.columns.tolist()
features.remove('date')

for feature in features:
    print(datasus_df[datasus_df[feature] < 0], "\n")
# Out:
# Empty DataFrame
# Columns: [date, hospitalizations, average_stay, deaths, mortality_rate]
# Index: []
#
# Empty DataFrame
# Columns: [date, hospitalizations, average_stay, deaths, mortality_rate]
# Index: []
#
# Empty DataFrame
# Columns: [date, hospitalizations, average_stay, deaths, mortality_rate]
# Index: []
#
# Empty DataFrame
# Columns: [date, hospitalizations, average_stay, deaths, mortality_rate]
# Index: []

# %%
for feature in features:
    plt.figure(figsize=(8, 6))
    plt.scatter(datasus_df['date'], datasus_df[feature])
    plt.title('Detecção de Outliers com Scatter Plot')
    plt.xlabel('Date')
    plt.ylabel(feature)
    plt.show()

# %%
for feature in features:
    plt.figure(figsize=(15, 6))
    plt.plot(datasus_df['date'], datasus_df[feature], marker='o', label=feature)
    plt.title(f'{feature} ao longo do tempo')
    plt.xlabel('Data')
    plt.ylabel(feature)
    plt.grid(True)
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
datasus_df
# Out:
#           date  hospitalizations  average_stay  deaths  mortality_rate
# 0   1998-01-01              3905           6.3     229            5.86
# 1   1998-02-01              3502           5.8     200            5.71
# 2   1998-03-01              4322           6.0     221            5.11
# 3   1998-04-01              4132           6.0     236            5.71
# 4   1998-05-01              4434           6.0     261            5.89
# ..         ...               ...           ...     ...             ...
# 316 2024-05-01              3172           6.7     313            9.87
# 317 2024-06-01              3640           6.6     329            9.04
# 318 2024-07-01              3689           6.5     338            9.16
# 319 2024-08-01              3846           6.8     389           10.11
# 320 2024-09-01              3426           6.9     298            8.70
#
# [321 rows x 5 columns]

# %% [markdown]
# ### Média movel

# %%
datasus_df['hospitalizations_moving_avg_3'] = datasus_df['hospitalizations'].rolling(window=3).mean()
datasus_df['deaths_moving_avg_3']           = datasus_df['deaths'].rolling(window=3).mean()

datasus_df
# Out:
#           date  hospitalizations  average_stay  deaths  mortality_rate  \
# 0   1998-01-01              3905           6.3     229            5.86
# 1   1998-02-01              3502           5.8     200            5.71
# 2   1998-03-01              4322           6.0     221            5.11
# 3   1998-04-01              4132           6.0     236            5.71
# 4   1998-05-01              4434           6.0     261            5.89
# ..         ...               ...           ...     ...             ...
# 316 2024-05-01              3172           6.7     313            9.87
# 317 2024-06-01              3640           6.6     329            9.04
# 318 2024-07-01              3689           6.5     338            9.16
# 319 2024-08-01              3846           6.8     389           10.11
# 320 2024-09-01              3426           6.9     298            8.70
#
#      hospitalizations_moving_avg_3  deaths_moving_avg_3
# 0                              NaN                  NaN
# 1                              NaN                  NaN
# 2                      3909.666667           216.666667
# 3                      3985.333333           219.000000
# 4                      4296.000000           239.333333
# ..                             ...                  ...
# 316                    3297.000000           299.333333
# 317                    3380.333333           316.666667
# 318                    3500.333333           326.666667
# 319                    3725.000000           352.000000
# 320                    3653.666667           341.666667
#
# [321 rows x 7 columns]

# %% [markdown]
# ### Lags

# %%
lags = [3, 6, 12]

for lag in lags:
    for feature in features:
        datasus_df[f'{feature}_lag_{lag}'] = datasus_df[feature].shift(lag)

datasus_df = datasus_df.dropna()

datasus_df
# Out:
#           date  hospitalizations  average_stay  deaths  mortality_rate  \
# 12  1999-01-01              4304           6.0     235            5.46
# 13  1999-02-01              3826           5.6     214            5.59
# 14  1999-03-01              4064           5.7     197            4.85
# 15  1999-04-01              4031           5.9     216            5.36
# 16  1999-05-01              4530           5.9     277            6.11
# ..         ...               ...           ...     ...             ...
# 316 2024-05-01              3172           6.7     313            9.87
# 317 2024-06-01              3640           6.6     329            9.04
# 318 2024-07-01              3689           6.5     338            9.16
# 319 2024-08-01              3846           6.8     389           10.11
# 320 2024-09-01              3426           6.9     298            8.70
#
#      hospitalizations_moving_avg_3  deaths_moving_avg_3  \
# 12                     4189.333333           231.000000
# 13                     4104.000000           221.333333
# 14                     4064.666667           215.333333
# 15                     3973.666667           209.000000
# 16                     4208.333333           230.000000
# ..                             ...                  ...
# 316                    3297.000000           299.333333
# 317                    3380.333333           316.666667
# 318                    3500.333333           326.666667
# 319                    3725.000000           352.000000
# 320                    3653.666667           341.666667
#
#      hospitalizations_lag_3  average_stay_lag_3  deaths_lag_3  \
# 12                   4353.0                 6.3         260.0
# 13                   4082.0                 5.8         243.0
# 14                   4182.0                 6.0         215.0
# 15                   4304.0                 6.0         235.0
# 16                   3826.0                 5.6         214.0
# ..                      ...                 ...           ...
# 316                  3176.0                 6.4         264.0
# 317                  3390.0                 6.7         277.0
# 318                  3329.0                 6.5         308.0
# 319                  3172.0                 6.7         313.0
# 320                  3640.0                 6.6         329.0
#
#      mortality_rate_lag_3  hospitalizations_lag_6  average_stay_lag_6  \
# 12                   5.97                  4004.0                 6.3
# 13                   5.95                  4093.0                 6.1
# 14                   5.14                  4336.0                 6.1
# 15                   5.46                  4353.0                 6.3
# 16                   5.59                  4082.0                 5.8
# ..                    ...                     ...                 ...
# 316                  8.31                  3543.0                 7.3
# 317                  8.17                  3424.0                 7.2
# 318                  9.25                  3739.0                 6.7
# 319                  9.87                  3176.0                 6.4
# 320                  9.04                  3390.0                 6.7
#
#      deaths_lag_6  mortality_rate_lag_6  hospitalizations_lag_12  \
# 12          336.0                  8.39                   3905.0
# 13          290.0                  7.09                   3502.0
# 14          283.0                  6.53                   4322.0
# 15          260.0                  5.97                   4132.0
# 16          243.0                  5.95                   4434.0
# ..            ...                   ...                      ...
# 316         342.0                  9.65                   3322.0
# 317         270.0                  7.89                   3374.0
# 318         344.0                  9.20                   3754.0
# 319         264.0                  8.31                   3768.0
# 320         277.0                  8.17                   3606.0
#
#      average_stay_lag_12  deaths_lag_12  mortality_rate_lag_12
# 12                   6.3          229.0                   5.86
# 13                   5.8          200.0                   5.71
# 14                   6.0          221.0                   5.11
# 15                   6.0          236.0                   5.71
# 16                   6.0          261.0                   5.89
# ..                   ...            ...                    ...
# 316                  7.0          337.0                  10.14
# 317                  6.8          338.0                  10.02
# 318                  6.8          364.0                   9.70
# 319                  6.9          344.0                   9.13
# 320                  6.9          329.0                   9.12
#
# [309 rows x 19 columns]

# %%
datasus_df.columns
# Out:
# Index(['date', 'hospitalizations', 'average_stay', 'deaths', 'mortality_rate',
#        'hospitalizations_moving_avg_3', 'deaths_moving_avg_3',
#        'hospitalizations_lag_3', 'average_stay_lag_3', 'deaths_lag_3',
#        'mortality_rate_lag_3', 'hospitalizations_lag_6', 'average_stay_lag_6',
#        'deaths_lag_6', 'mortality_rate_lag_6', 'hospitalizations_lag_12',
#        'average_stay_lag_12', 'deaths_lag_12', 'mortality_rate_lag_12'],
#       dtype='object')

# %% [markdown]
# **Tranformando para int**

# %%
lags = [3, 6, 12]
integer_features = ['hospitalizations', 'deaths']

for lag in lags:
    for feature in integer_features:
        datasus_df[f'{feature}_lag_{lag}'] = datasus_df[f'{feature}_lag_{lag}'].astype(int)

datasus_df
# Out:
# <ipython-input-81-0bfab383a062>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datasus_df[f'{feature}_lag_{lag}'] = datasus_df[f'{feature}_lag_{lag}'].astype(int)
# <ipython-input-81-0bfab383a062>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datasus_df[f'{feature}_lag_{lag}'] = datasus_df[f'{feature}_lag_{lag}'].astype(int)
# <ipython-input-81-0bfab383a062>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datasus_df[f'{feature}_lag_{lag}'] = datasus_df[f'{feature}_lag_{lag}'].astype(int)
# <ipython-input-81-0bfab383a062>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datasus_df[f'{feature}_lag_{lag}'] = datasus_df[f'{feature}_lag_{lag}'].astype(int)
# <ipython-input-81-0bfab383a062>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datasus_df[f'{feature}_lag_{lag}'] = datasus_df[f'{feature}_lag_{lag}'].astype(int)
# <ipython-input-81-0bfab383a062>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datasus_df[f'{feature}_lag_{lag}'] = datasus_df[f'{feature}_lag_{lag}'].astype(int)
#           date  hospitalizations  average_stay  deaths  mortality_rate  \
# 12  1999-01-01              4304           6.0     235            5.46
# 13  1999-02-01              3826           5.6     214            5.59
# 14  1999-03-01              4064           5.7     197            4.85
# 15  1999-04-01              4031           5.9     216            5.36
# 16  1999-05-01              4530           5.9     277            6.11
# ..         ...               ...           ...     ...             ...
# 316 2024-05-01              3172           6.7     313            9.87
# 317 2024-06-01              3640           6.6     329            9.04
# 318 2024-07-01              3689           6.5     338            9.16
# 319 2024-08-01              3846           6.8     389           10.11
# 320 2024-09-01              3426           6.9     298            8.70
#
#      hospitalizations_moving_avg_3  deaths_moving_avg_3  \
# 12                     4189.333333           231.000000
# 13                     4104.000000           221.333333
# 14                     4064.666667           215.333333
# 15                     3973.666667           209.000000
# 16                     4208.333333           230.000000
# ..                             ...                  ...
# 316                    3297.000000           299.333333
# 317                    3380.333333           316.666667
# 318                    3500.333333           326.666667
# 319                    3725.000000           352.000000
# 320                    3653.666667           341.666667
#
#      hospitalizations_lag_3  average_stay_lag_3  deaths_lag_3  \
# 12                     4353                 6.3           260
# 13                     4082                 5.8           243
# 14                     4182                 6.0           215
# 15                     4304                 6.0           235
# 16                     3826                 5.6           214
# ..                      ...                 ...           ...
# 316                    3176                 6.4           264
# 317                    3390                 6.7           277
# 318                    3329                 6.5           308
# 319                    3172                 6.7           313
# 320                    3640                 6.6           329
#
#      mortality_rate_lag_3  hospitalizations_lag_6  average_stay_lag_6  \
# 12                   5.97                    4004                 6.3
# 13                   5.95                    4093                 6.1
# 14                   5.14                    4336                 6.1
# 15                   5.46                    4353                 6.3
# 16                   5.59                    4082                 5.8
# ..                    ...                     ...                 ...
# 316                  8.31                    3543                 7.3
# 317                  8.17                    3424                 7.2
# 318                  9.25                    3739                 6.7
# 319                  9.87                    3176                 6.4
# 320                  9.04                    3390                 6.7
#
#      deaths_lag_6  mortality_rate_lag_6  hospitalizations_lag_12  \
# 12            336                  8.39                     3905
# 13            290                  7.09                     3502
# 14            283                  6.53                     4322
# 15            260                  5.97                     4132
# 16            243                  5.95                     4434
# ..            ...                   ...                      ...
# 316           342                  9.65                     3322
# 317           270                  7.89                     3374
# 318           344                  9.20                     3754
# 319           264                  8.31                     3768
# 320           277                  8.17                     3606
#
#      average_stay_lag_12  deaths_lag_12  mortality_rate_lag_12
# 12                   6.3            229                   5.86
# 13                   5.8            200                   5.71
# 14                   6.0            221                   5.11
# 15                   6.0            236                   5.71
# 16                   6.0            261                   5.89
# ..                   ...            ...                    ...
# 316                  7.0            337                  10.14
# 317                  6.8            338                  10.02
# 318                  6.8            364                   9.70
# 319                  6.9            344                   9.13
# 320                  6.9            329                   9.12
#
# [309 rows x 19 columns]

# %% [markdown]
# ## Removendo features 'hospitalizations', 'average_stay', 'deaths', 'mortality_rate',

# %%
datasus_df = datasus_df.drop(['average_stay', 'deaths', 'mortality_rate'], axis=1)

datasus_df.columns
# Out:
# Index(['date', 'hospitalizations_moving_avg_3', 'deaths_moving_avg_3',
#        'hospitalizations_lag_3', 'average_stay_lag_3', 'deaths_lag_3',
#        'mortality_rate_lag_3', 'hospitalizations_lag_6', 'average_stay_lag_6',
#        'deaths_lag_6', 'mortality_rate_lag_6', 'hospitalizations_lag_12',
#        'average_stay_lag_12', 'deaths_lag_12', 'mortality_rate_lag_12'],
#       dtype='object')

# %% [markdown]
# ## Dados após 2000

# %%
datasus_df = datasus_df[datasus_df['date'] >= '2000-12-1']

# %% [markdown]
# ## Unir com INMET

# %%
datasus_df['date'] = datasus_df['date'].dt.to_period('M')
# datasus_df = datasus_df[11:]

datasus_df.reset_index(drop=True, inplace=True)
datasus_df
# Out:
#         date  hospitalizations_moving_avg_3  deaths_moving_avg_3  \
# 0    2000-12                    4327.666667           258.333333
# 1    2001-01                    4209.000000           239.333333
# 2    2001-02                    4062.000000           225.666667
# 3    2001-03                    3859.333333           203.666667
# 4    2001-04                    3856.000000           216.333333
# ..       ...                            ...                  ...
# 281  2024-05                    3297.000000           299.333333
# 282  2024-06                    3380.333333           316.666667
# 283  2024-07                    3500.333333           326.666667
# 284  2024-08                    3725.000000           352.000000
# 285  2024-09                    3653.666667           341.666667
#
#      hospitalizations_lag_3  average_stay_lag_3  deaths_lag_3  \
# 0                      4365                 6.4           293
# 1                      4388                 6.3           275
# 2                      4329                 6.1           258
# 3                      4266                 6.1           242
# 4                      4032                 5.9           218
# ..                      ...                 ...           ...
# 281                    3176                 6.4           264
# 282                    3390                 6.7           277
# 283                    3329                 6.5           308
# 284                    3172                 6.7           313
# 285                    3640                 6.6           329
#
#      mortality_rate_lag_3  hospitalizations_lag_6  average_stay_lag_6  \
# 0                    6.71                    4370                 5.9
# 1                    6.27                    4256                 6.0
# 2                    5.96                    4290                 5.8
# 3                    5.67                    4365                 6.4
# 4                    5.41                    4388                 6.3
# ..                    ...                     ...                 ...
# 281                  8.31                    3543                 7.3
# 282                  8.17                    3424                 7.2
# 283                  9.25                    3739                 6.7
# 284                  9.87                    3176                 6.4
# 285                  9.04                    3390                 6.7
#
#      deaths_lag_6  mortality_rate_lag_6  hospitalizations_lag_12  \
# 0             255                  5.84                     4163
# 1             273                  6.41                     4048
# 2             315                  7.34                     4144
# 3             293                  6.71                     3953
# 4             275                  6.27                     4420
# ..            ...                   ...                      ...
# 281           342                  9.65                     3322
# 282           270                  7.89                     3374
# 283           344                  9.20                     3754
# 284           264                  8.31                     3768
# 285           277                  8.17                     3606
#
#      average_stay_lag_12  deaths_lag_12  mortality_rate_lag_12
# 0                    5.7            209                   5.02
# 1                    5.8            220                   5.43
# 2                    5.6            219                   5.28
# 3                    5.8            209                   5.29
# 4                    5.9            215                   4.86
# ..                   ...            ...                    ...
# 281                  7.0            337                  10.14
# 282                  6.8            338                  10.02
# 283                  6.8            364                   9.70
# 284                  6.9            344                   9.13
# 285                  6.9            329                   9.12
#
# [286 rows x 15 columns]

# %% [markdown]
# Pegando o csv

# %%
# csv_url = 'https://raw.githubusercontent.com/ThierrryScotto/trabalho_pratico/refs/heads/main/datasets/monthly_df_INMET.csv'
csv_url = '/content/monthly_df.csv'

monthly_df_inmet = pd.read_csv(csv_url)

monthly_df_inmet.head(5)
# Out:
#       date  heat_index  standard_deviation  mean_temperature  mean_humidity  \
# 0  2000-12   30.079677            4.615565             28.94          51.32
# 1  2001-01   31.907742            4.864888             29.69          59.10
# 2  2001-02   32.959643            3.889432             30.08          60.14
# 3  2001-03   32.071290            3.585808             29.82          56.61
# 4  2001-04   25.963667            3.307106             25.37          64.77
#
#    mean_wind_speed  max_temperature  min_temperature  sum_heat_index  \
# 0             2.00             35.4             22.2          932.47
# 1             2.19             35.4             21.4          989.14
# 2             2.33             34.2             23.5          922.87
# 3             2.21             34.4             25.1          994.21
# 4             1.68             30.8             19.3          778.91
#
#    percentil_95  percentil_99  lag_heat_index_1  lag_heat_index_2  \
# 0        38.025       38.5520         26.305667         23.427742
# 1        38.780       39.5900         30.079677         26.305667
# 2        38.625       38.8030         31.907742         30.079677
# 3        37.065       37.7400         32.959643         31.907742
# 4        30.751       32.1117         32.071290         32.959643
#
#    lag_heat_index_3
# 0         21.801111
# 1         23.427742
# 2         26.305667
# 3         30.079677
# 4         31.907742

# %%
monthly_df_inmet.shape
# Out:
# (287, 14)

# %%
datasus_df.shape
# Out:
# (286, 15)

# %%
monthly_inmet_datasus = pd.concat([monthly_df_inmet, datasus_df], axis=1)

monthly_inmet_datasus
# Out:
#         date  heat_index  standard_deviation  mean_temperature  mean_humidity  \
# 0    2000-12   30.079677            4.615565             28.94          51.32
# 1    2001-01   31.907742            4.864888             29.69          59.10
# 2    2001-02   32.959643            3.889432             30.08          60.14
# 3    2001-03   32.071290            3.585808             29.82          56.61
# 4    2001-04   25.963667            3.307106             25.37          64.77
# ..       ...         ...                 ...               ...            ...
# 282  2024-06   22.028667            5.929766             21.99          64.67
# 283  2024-07   17.503548            5.561158             17.91          67.87
# 284  2024-08   20.590000            5.447565             20.85          60.29
# 285  2024-09   24.021000            4.649160             23.80          63.00
# 286  2024-10   26.017742            4.499940             25.51          57.48
#
#      mean_wind_speed  max_temperature  min_temperature  sum_heat_index  \
# 0               2.00             35.4             22.2          932.47
# 1               2.19             35.4             21.4          989.14
# 2               2.33             34.2             23.5          922.87
# 3               2.21             34.4             25.1          994.21
# 4               1.68             30.8             19.3          778.91
# ..               ...              ...              ...             ...
# 282             1.66             31.5             11.6          660.86
# 283             1.31             28.9              9.8          542.61
# 284             1.61             31.1             12.5          638.29
# 285             1.42             33.7             18.0          720.63
# 286             1.90             33.6             19.3          806.55
#
#      percentil_95  ...  deaths_lag_3  mortality_rate_lag_3  \
# 0          38.025  ...         293.0                  6.71
# 1          38.780  ...         275.0                  6.27
# 2          38.625  ...         258.0                  5.96
# 3          37.065  ...         242.0                  5.67
# 4          30.751  ...         218.0                  5.41
# ..            ...  ...           ...                   ...
# 282        30.344  ...         277.0                  8.17
# 283        26.970  ...         308.0                  9.25
# 284        29.725  ...         313.0                  9.87
# 285        33.113  ...         329.0                  9.04
# 286        33.905  ...           NaN                   NaN
#
#      hospitalizations_lag_6  average_stay_lag_6 deaths_lag_6  \
# 0                    4370.0                 5.9        255.0
# 1                    4256.0                 6.0        273.0
# 2                    4290.0                 5.8        315.0
# 3                    4365.0                 6.4        293.0
# 4                    4388.0                 6.3        275.0
# ..                      ...                 ...          ...
# 282                  3424.0                 7.2        270.0
# 283                  3739.0                 6.7        344.0
# 284                  3176.0                 6.4        264.0
# 285                  3390.0                 6.7        277.0
# 286                     NaN                 NaN          NaN
#
#      mortality_rate_lag_6  hospitalizations_lag_12  average_stay_lag_12  \
# 0                    5.84                   4163.0                  5.7
# 1                    6.41                   4048.0                  5.8
# 2                    7.34                   4144.0                  5.6
# 3                    6.71                   3953.0                  5.8
# 4                    6.27                   4420.0                  5.9
# ..                    ...                      ...                  ...
# 282                  7.89                   3374.0                  6.8
# 283                  9.20                   3754.0                  6.8
# 284                  8.31                   3768.0                  6.9
# 285                  8.17                   3606.0                  6.9
# 286                   NaN                      NaN                  NaN
#
#      deaths_lag_12  mortality_rate_lag_12
# 0            209.0                   5.02
# 1            220.0                   5.43
# 2            219.0                   5.28
# 3            209.0                   5.29
# 4            215.0                   4.86
# ..             ...                    ...
# 282          338.0                  10.02
# 283          364.0                   9.70
# 284          344.0                   9.13
# 285          329.0                   9.12
# 286            NaN                    NaN
#
# [287 rows x 29 columns]

# %% [markdown]
# **removendo duas últimas linhas**

# %%
monthly_inmet_datasus = monthly_inmet_datasus.drop(monthly_inmet_datasus.tail(1).index)

monthly_inmet_datasus.tail(5)
# Out:
#         date  heat_index  standard_deviation  mean_temperature  mean_humidity  \
# 281  2024-05   20.278710            6.342679             20.00          76.16
# 282  2024-06   22.028667            5.929766             21.99          64.67
# 283  2024-07   17.503548            5.561158             17.91          67.87
# 284  2024-08   20.590000            5.447565             20.85          60.29
# 285  2024-09   24.021000            4.649160             23.80          63.00
#
#      mean_wind_speed  max_temperature  min_temperature  sum_heat_index  \
# 281             1.62             32.5             12.7          628.64
# 282             1.66             31.5             11.6          660.86
# 283             1.31             28.9              9.8          542.61
# 284             1.61             31.1             12.5          638.29
# 285             1.42             33.7             18.0          720.63
#
#      percentil_95  ...  deaths_lag_3  mortality_rate_lag_3  \
# 281        33.985  ...         264.0                  8.31
# 282        30.344  ...         277.0                  8.17
# 283        26.970  ...         308.0                  9.25
# 284        29.725  ...         313.0                  9.87
# 285        33.113  ...         329.0                  9.04
#
#      hospitalizations_lag_6  average_stay_lag_6 deaths_lag_6  \
# 281                  3543.0                 7.3        342.0
# 282                  3424.0                 7.2        270.0
# 283                  3739.0                 6.7        344.0
# 284                  3176.0                 6.4        264.0
# 285                  3390.0                 6.7        277.0
#
#      mortality_rate_lag_6  hospitalizations_lag_12  average_stay_lag_12  \
# 281                  9.65                   3322.0                  7.0
# 282                  7.89                   3374.0                  6.8
# 283                  9.20                   3754.0                  6.8
# 284                  8.31                   3768.0                  6.9
# 285                  8.17                   3606.0                  6.9
#
#      deaths_lag_12  mortality_rate_lag_12
# 281          337.0                  10.14
# 282          338.0                  10.02
# 283          364.0                   9.70
# 284          344.0                   9.13
# 285          329.0                   9.12
#
# [5 rows x 29 columns]

# %% [markdown]
# **Salvando como csv**

# %%
monthly_inmet_datasus.to_csv('monthly_inmet_datasus.csv', index=False)

# %% [markdown]
# # Pré-processamento dados geográficos MapBiomas

# %%
url = 'https://raw.githubusercontent.com/ThierrryScotto/trabalho_pratico/refs/heads/main/datasets/dados_geograficos.csv'

map_biomas_df = pd.read_csv(url)

map_biomas_df
# Out:
#         date  deforestation  primary_forest_loss        favela  urbanized_area
# 0    2000-12    6164.578305                   150  1865.773354    14831.872329
# 1    2001-01    6390.131585                   201  1903.810075    14972.162742
# 2    2001-02    6390.131585                   201  1903.810075    14972.162742
# 3    2001-03    6390.131585                   201  1903.810075    14972.162742
# 4    2001-04    6390.131585                   201  1903.810075    14972.162742
# ..       ...            ...                   ...          ...             ...
# 272  2023-08    8843.702904                    12  2133.371088    16874.949657
# 273  2023-09    8843.702904                    12  2133.371088    16874.949657
# 274  2023-10    8843.702904                    12  2133.371088    16874.949657
# 275  2023-11    8843.702904                    12  2133.371088    16874.949657
# 276  2023-12    8843.702904                    12  2133.371088    16874.949657
#
# [277 rows x 5 columns]

# %% [markdown]
# ### converter colunas para inteiros

# %%
columns = ['deforestation', 'favela', 'urbanized_area']

for feature in columns:
    map_biomas_df[feature] = map_biomas_df[feature].astype(int)

map_biomas_df
# Out:
#         date  deforestation  primary_forest_loss   favela  urbanized_area
# 0    2000-12           6164                   150    1865           14831
# 1    2001-01           6390                   201    1903           14972
# 2    2001-02           6390                   201    1903           14972
# 3    2001-03           6390                   201    1903           14972
# 4    2001-04           6390                   201    1903           14972
# ..       ...            ...                   ...     ...             ...
# 272  2023-08           8843                    12    2133           16874
# 273  2023-09           8843                    12    2133           16874
# 274  2023-10           8843                    12    2133           16874
# 275  2023-11           8843                    12    2133           16874
# 276  2023-12           8843                    12    2133           16874
#
# [277 rows x 5 columns]

# %%
map_biomas_df.describe()
# Out:
#        deforestation  primary_forest_loss        favela  urbanized_area
# count     277.000000            277.000000   277.000000      277.000000
# mean     8069.140794             94.895307  2052.018051    16158.104693
# std       695.720343            111.093543    62.672397      592.951674
# min      6164.000000             12.000000  1865.000000    14831.000000
# 25%      7605.000000             34.000000  2022.000000    15608.000000
# 50%      8291.000000             74.000000  2065.000000    16380.000000
# 75%      8637.000000            101.000000  2102.000000    16694.000000
# max      8843.000000            576.000000  2133.000000    16874.000000

# %%
features = map_biomas_df.columns.tolist()
features.remove('date')

for feature in features:
    plt.figure(figsize=(8, 6))
    plt.scatter(map_biomas_df['date'], map_biomas_df[feature])
    plt.title('Detecção de Outliers com Scatter Plot')
    plt.xlabel('Date')
    plt.ylabel(feature)
    plt.show()

# %% [markdown]
# ## Unir com o dataset

# %% [markdown]
# Usando o csv

# %%
# csv_url = 'https://raw.githubusercontent.com/ThierrryScotto/trabalho_pratico/refs/heads/main/datasets/monthly_inmet_datasus.csv'
csv_url = '/content/monthly_inmet_datasus.csv'

monthly_inmet_datasus_df = pd.read_csv(csv_url)

monthly_inmet_datasus_df.head(5)
# Out:
#       date  heat_index  standard_deviation  mean_temperature  mean_humidity  \
# 0  2000-12   30.079677            4.615565             28.94          51.32
# 1  2001-01   31.907742            4.864888             29.69          59.10
# 2  2001-02   32.959643            3.889432             30.08          60.14
# 3  2001-03   32.071290            3.585808             29.82          56.61
# 4  2001-04   25.963667            3.307106             25.37          64.77
#
#    mean_wind_speed  max_temperature  min_temperature  sum_heat_index  \
# 0             2.00             35.4             22.2          932.47
# 1             2.19             35.4             21.4          989.14
# 2             2.33             34.2             23.5          922.87
# 3             2.21             34.4             25.1          994.21
# 4             1.68             30.8             19.3          778.91
#
#    percentil_95  percentil_99  lag_heat_index_1  lag_heat_index_2  \
# 0        38.025       38.5520         26.305667         23.427742
# 1        38.780       39.5900         30.079677         26.305667
# 2        38.625       38.8030         31.907742         30.079677
# 3        37.065       37.7400         32.959643         31.907742
# 4        30.751       32.1117         32.071290         32.959643
#
#    lag_heat_index_3  hospitalizations  average_stay  deaths  mortality_rate
# 0         21.801111              4266           6.1     242            5.67
# 1         23.427742              4032           5.9     218            5.41
# 2         26.305667              3888           5.8     217            5.58
# 3         30.079677              3658           5.8     176            4.81
# 4         31.907742              4022           5.8     256            6.36

# %% [markdown]
# ### Removendo dados de 2024

# %%
monthly_inmet_datasus_df = monthly_inmet_datasus_df[:len(map_biomas_df)]
monthly_inmet_datasus_df
# Out:
#         date  heat_index  standard_deviation  mean_temperature  mean_humidity  \
# 0    2000-12   30.079677            4.615565             28.94          51.32
# 1    2001-01   31.907742            4.864888             29.69          59.10
# 2    2001-02   32.959643            3.889432             30.08          60.14
# 3    2001-03   32.071290            3.585808             29.82          56.61
# 4    2001-04   25.963667            3.307106             25.37          64.77
# ..       ...         ...                 ...               ...            ...
# 272  2023-08   22.680968            5.464467             22.86          52.13
# 273  2023-09   23.058000            5.559752             22.70          69.97
# 274  2023-10   23.510645            3.787990             23.30          63.58
# 275  2023-11   26.595000            3.669000             25.96          61.17
# 276  2023-12   32.380645            6.370596             29.62          58.16
#
#      mean_wind_speed  max_temperature  min_temperature  sum_heat_index  \
# 0               2.00             35.4             22.2          932.47
# 1               2.19             35.4             21.4          989.14
# 2               2.33             34.2             23.5          922.87
# 3               2.21             34.4             25.1          994.21
# 4               1.68             30.8             19.3          778.91
# ..               ...              ...              ...             ...
# 272             1.62             32.3             15.2          703.11
# 273             1.69             34.9             15.6          691.74
# 274             1.84             31.6             16.9          728.83
# 275             1.65             33.5             19.9          797.85
# 276             1.80             37.9             21.1         1003.80
#
#      percentil_95  percentil_99  lag_heat_index_1  lag_heat_index_2  \
# 0          38.025       38.5520         26.305667         23.427742
# 1          38.780       39.5900         30.079677         26.305667
# 2          38.625       38.8030         31.907742         30.079677
# 3          37.065       37.7400         32.959643         31.907742
# 4          30.751       32.1117         32.071290         32.959643
# ..            ...           ...               ...               ...
# 272        31.335       33.0020         19.769677         21.014000
# 273        33.460       36.6514         22.680968         19.769677
# 274        29.465       32.1660         23.058000         22.680968
# 275        31.954       34.2029         23.510645         23.058000
# 276        42.350       44.7380         26.595000         23.510645
#
#      lag_heat_index_3  hospitalizations  average_stay  deaths  mortality_rate
# 0           21.801111              4266           6.1     242            5.67
# 1           23.427742              4032           5.9     218            5.41
# 2           26.305667              3888           5.8     217            5.58
# 3           30.079677              3658           5.8     176            4.81
# 4           31.907742              4022           5.8     256            6.36
# ..                ...               ...           ...     ...             ...
# 272         23.174194              3768           6.9     344            9.13
# 273         21.014000              3606           6.9     329            9.12
# 274         19.769677              3697           7.5     341            9.22
# 275         22.680968              3543           7.3     342            9.65
# 276         23.058000              3424           7.2     270            7.89
#
# [277 rows x 18 columns]

# %% [markdown]
# ### Unindo os datasets

# %%
for feature in features:
    monthly_inmet_datasus_df[f'{feature}'] = map_biomas_df[feature]

monthly_inmet_datasus_df
# Out:
# <ipython-input-87-d21e730650dd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monthly_inmet_datasus_df[f'{feature}'] = map_biomas_df[feature]
# <ipython-input-87-d21e730650dd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monthly_inmet_datasus_df[f'{feature}'] = map_biomas_df[feature]
# <ipython-input-87-d21e730650dd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monthly_inmet_datasus_df[f'{feature}'] = map_biomas_df[feature]
# <ipython-input-87-d21e730650dd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monthly_inmet_datasus_df[f'{feature}'] = map_biomas_df[feature]
#         date  heat_index  standard_deviation  mean_temperature  mean_humidity  \
# 0    2000-12   30.079677            4.615565             28.94          51.32
# 1    2001-01   31.907742            4.864888             29.69          59.10
# 2    2001-02   32.959643            3.889432             30.08          60.14
# 3    2001-03   32.071290            3.585808             29.82          56.61
# 4    2001-04   25.963667            3.307106             25.37          64.77
# ..       ...         ...                 ...               ...            ...
# 272  2023-08   22.680968            5.464467             22.86          52.13
# 273  2023-09   23.058000            5.559752             22.70          69.97
# 274  2023-10   23.510645            3.787990             23.30          63.58
# 275  2023-11   26.595000            3.669000             25.96          61.17
# 276  2023-12   32.380645            6.370596             29.62          58.16
#
#      mean_wind_speed  max_temperature  min_temperature  sum_heat_index  \
# 0               2.00             35.4             22.2          932.47
# 1               2.19             35.4             21.4          989.14
# 2               2.33             34.2             23.5          922.87
# 3               2.21             34.4             25.1          994.21
# 4               1.68             30.8             19.3          778.91
# ..               ...              ...              ...             ...
# 272             1.62             32.3             15.2          703.11
# 273             1.69             34.9             15.6          691.74
# 274             1.84             31.6             16.9          728.83
# 275             1.65             33.5             19.9          797.85
# 276             1.80             37.9             21.1         1003.80
#
#      percentil_95  ...  lag_heat_index_2  lag_heat_index_3  hospitalizations  \
# 0          38.025  ...         23.427742         21.801111              4266
# 1          38.780  ...         26.305667         23.427742              4032
# 2          38.625  ...         30.079677         26.305667              3888
# 3          37.065  ...         31.907742         30.079677              3658
# 4          30.751  ...         32.959643         31.907742              4022
# ..            ...  ...               ...               ...               ...
# 272        31.335  ...         21.014000         23.174194              3768
# 273        33.460  ...         19.769677         21.014000              3606
# 274        29.465  ...         22.680968         19.769677              3697
# 275        31.954  ...         23.058000         22.680968              3543
# 276        42.350  ...         23.510645         23.058000              3424
#
#      average_stay  deaths  mortality_rate  deforestation  \
# 0             6.1     242            5.67           6164
# 1             5.9     218            5.41           6390
# 2             5.8     217            5.58           6390
# 3             5.8     176            4.81           6390
# 4             5.8     256            6.36           6390
# ..            ...     ...             ...            ...
# 272           6.9     344            9.13           8843
# 273           6.9     329            9.12           8843
# 274           7.5     341            9.22           8843
# 275           7.3     342            9.65           8843
# 276           7.2     270            7.89           8843
#
#      primary_forest_loss   favela  urbanized_area
# 0                     150    1865           14831
# 1                     201    1903           14972
# 2                     201    1903           14972
# 3                     201    1903           14972
# 4                     201    1903           14972
# ..                    ...     ...             ...
# 272                    12    2133           16874
# 273                    12    2133           16874
# 274                    12    2133           16874
# 275                    12    2133           16874
# 276                    12    2133           16874
#
# [277 rows x 22 columns]

# %% [markdown]
# ### Salvando csv

# %%
monthly_inmet_datasus_df.to_csv('dataset_with_geographic_data.csv', index=False)

# %%
monthly_inmet_datasus_df
# Out:
#         date  heat_index  standard_deviation  mean_temperature  mean_humidity  \
# 0    2000-12   30.079677            4.615565             28.94          51.32
# 1    2001-01   31.907742            4.864888             29.69          59.10
# 2    2001-02   32.959643            3.889432             30.08          60.14
# 3    2001-03   32.071290            3.585808             29.82          56.61
# 4    2001-04   25.963667            3.307106             25.37          64.77
# ..       ...         ...                 ...               ...            ...
# 272  2023-08   22.680968            5.464467             22.86          52.13
# 273  2023-09   23.058000            5.559752             22.70          69.97
# 274  2023-10   23.510645            3.787990             23.30          63.58
# 275  2023-11   26.595000            3.669000             25.96          61.17
# 276  2023-12   32.380645            6.370596             29.62          58.16
#
#      mean_wind_speed  max_temperature  min_temperature  sum_heat_index  \
# 0               2.00             35.4             22.2          932.47
# 1               2.19             35.4             21.4          989.14
# 2               2.33             34.2             23.5          922.87
# 3               2.21             34.4             25.1          994.21
# 4               1.68             30.8             19.3          778.91
# ..               ...              ...              ...             ...
# 272             1.62             32.3             15.2          703.11
# 273             1.69             34.9             15.6          691.74
# 274             1.84             31.6             16.9          728.83
# 275             1.65             33.5             19.9          797.85
# 276             1.80             37.9             21.1         1003.80
#
#      percentil_95  ...  lag_heat_index_2  lag_heat_index_3  hospitalizations  \
# 0          38.025  ...         23.427742         21.801111              4266
# 1          38.780  ...         26.305667         23.427742              4032
# 2          38.625  ...         30.079677         26.305667              3888
# 3          37.065  ...         31.907742         30.079677              3658
# 4          30.751  ...         32.959643         31.907742              4022
# ..            ...  ...               ...               ...               ...
# 272        31.335  ...         21.014000         23.174194              3768
# 273        33.460  ...         19.769677         21.014000              3606
# 274        29.465  ...         22.680968         19.769677              3697
# 275        31.954  ...         23.058000         22.680968              3543
# 276        42.350  ...         23.510645         23.058000              3424
#
#      average_stay  deaths  mortality_rate  deforestation  \
# 0             6.1     242            5.67           6164
# 1             5.9     218            5.41           6390
# 2             5.8     217            5.58           6390
# 3             5.8     176            4.81           6390
# 4             5.8     256            6.36           6390
# ..            ...     ...             ...            ...
# 272           6.9     344            9.13           8843
# 273           6.9     329            9.12           8843
# 274           7.5     341            9.22           8843
# 275           7.3     342            9.65           8843
# 276           7.2     270            7.89           8843
#
#      primary_forest_loss   favela  urbanized_area
# 0                     150    1865           14831
# 1                     201    1903           14972
# 2                     201    1903           14972
# 3                     201    1903           14972
# 4                     201    1903           14972
# ..                    ...     ...             ...
# 272                    12    2133           16874
# 273                    12    2133           16874
# 274                    12    2133           16874
# 275                    12    2133           16874
# 276                    12    2133           16874
#
# [277 rows x 22 columns]
